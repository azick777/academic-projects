# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sagemaker.amazon.amazon_estimator import get_image_uri
from sklearn.model_selection import train_test_split
import boto3
import numpy as np
import sagemaker.amazon.common as smac
import io
from io import StringIO
import sagemaker
from sagemaker import get_execution_role
import time
from sklearn import metrics
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, classification_report, average_precision_score, precision_score, recall_score
from sagemaker.xgboost.estimator import XGBoost
from sagemaker.session import s3_input, Session
import os
from sagemaker.predictor import csv_serializer, json_deserializer

# %%
# download the data
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data', header = None)

# %% [markdown]
# ## 1. Data Preparation

# %%
data.columns = ["id","diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean",
                "compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean",
                "radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se",
                "concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst", 
                "perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst", 
                "concave points_worst","symmetry_worst","fractal_dimension_worst"]

# %%
df = data.drop(columns={"id"},axis=1)
df['diagnosis']=df['diagnosis'].map({'M':1,'B':0})
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
X = df.copy()
X.drop(columns=['diagnosis'], axis=1, inplace=True)
y = df['diagnosis']

# %%
# create a holdout set, 20%
X_train, X_holdout, y_train, y_holdout = train_test_split(X,y, test_size=0.20)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_holdout.shape)
print(y_holdout.shape)
# Out:
# (455, 30)
# (455,)
# (114, 30)
# (114,)

# %% [markdown]
# ## 2.1 Training Linear model

# %%
bucket = 'uncc-bucket'
filename = 'wdbc.data'
train_path = f"ml-lab/{filename}"
s3_train_data = f"s3://{bucket}/{train_path}"
output_location = f's3://{bucket}/ml-lab/output'

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, np.array(X_train).astype('float32'), np.array(y_train).astype('float32'))
buf.seek(0)
boto3.resource('s3').Bucket(bucket).Object(f'{train_path}').upload_fileobj(buf)

# %%
container = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
sess = sagemaker.Session()
role = get_execution_role()
linear = sagemaker.estimator.Estimator(container,
                                   role, 
                                   train_instance_count=1, 
                                   train_instance_type='ml.m5.large',
                                   output_path=output_location,
                                   sagemaker_session=sess)

linear.set_hyperparameters(feature_dim=30,
                           predictor_type='binary_classifier',
                           mini_batch_size=200)

linear.fit({'train': s3_train_data}, job_name=f"job-abalone-{int(time.time())}")
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-10-22 15:01:46 Starting - Starting the training job...
# 2020-10-22 15:01:48 Starting - Launching requested ML instances.........
# 2020-10-22 15:03:20 Starting - Preparing the instances for training...
# 2020-10-22 15:04:03 Downloading - Downloading input data...
# 2020-10-22 15:04:27 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/22/2020 15:05:01 INFO 140123020961600] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/22/2020 15:05:01 INFO 140123020961600] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'30', u'mini_batch_size': u'200', u'predictor_type': u'binary_classifier'}
# [10/22/2020 15:05:01 INFO 140123020961600] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/22/2020 15:05:01 WARNING 140123020961600] Loggers have already been setup.
# Process 1 is a worker.
# [10/22/2020 15:05:01 INFO 140123020961600] Using default worker.
# [10/22/2020 15:05:01 INFO 140123020961600] Checkpoint loading and saving are disabled.
# [2020-10-22 15:05:01.289] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 33600}
# [10/22/2020 15:05:01 INFO 140123020961600] Create Store: local
# [2020-10-22 15:05:01.318] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 26, "num_examples": 3, "num_bytes": 76440}
# [10/22/2020 15:05:01 INFO 140123020961600] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f
#progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 455, "sum": 455.0, "min": 455}, "Total Batches Seen": {"count": 1, "max": 49, "sum": 49.0, "min": 49}, "Total Records Seen": {"count": 1, "max": 7480, "sum": 7480.0, "min": 7480}, "Max Records Seen Between Resets": {"count": 1, "max": 455, "sum": 455.0, "min": 455}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1603379102.82714, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1603379102.729438}
#
# [10/22/2020 15:05:02 INFO 140123020961600] #throughput_metric: host=algo-1, train throughput=4648.88302084 records/second
# [10/22/2020 15:05:02 WARNING 140123020961600] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/22/2020 15:05:02 WARNING 140123020961600] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-10-22 15:05:02.829] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 1, "num_examples": 1, "num_bytes": 33600}
# [2020-10-22 15:05:03.045] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 37, "duration": 213, "num_examples": 3, "num_bytes": 76440}
# [2020-10-22 15:05:03.073] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 39, "duration": 11, "num_examples": 3, "num_bytes": 76440}
# [10/22/2020 15:05:03 INFO 140123020961600] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.0647674539587)
# [10/22/2020 15:05:03 INFO 140123020961600] #train_score (algo-1) : ('binary_classification_accuracy', 0.9824175824175824)
# [10/22/2020 15:05:03 INFO 140123020961600] #train_score (algo-1) : ('binary_f_1.000', 0.9757575757575757)
# [10/22/2020 15:05:03 INFO 140123020961600] #train_score (algo-1) : ('precision', 0.9817073170731707)
# [10/22/2020 15:05:03 INFO 140123020961600] #train_score (algo-1) : ('recall', 0.9698795180722891)
# [10/22/2020 15:05:03 INFO 140123020961600] #train_score (algo-1) : ('roc_auc_score', 0.995601784299829)
# [10/22/2020 15:05:03 INFO 140123020961600] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.0647674539587
# [10/22/2020 15:05:03 INFO 140123020961600] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.982417582418
# [10/22/2020 15:05:03 INFO 140123020961600] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.975757575758
# [10/22/2020 15:05:03 INFO 140123020961600] #quality_metric: host=algo-1, train precision <score>=0.981707317073
# [10/22/2020 15:05:03 INFO 140123020961600] #quality_metric: host=algo-1, train recall <score>=0.969879518072
# [10/22/2020 15:05:03 INFO 140123020961600] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9956017843
# [10/22/2020 15:05:03 INFO 140123020961600] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [10/22/2020 15:05:03 INFO 140123020961600] Saved checkpoint to "/tmp/tmpZ0sWN8/mx-mod-0000.params"
# [10/22/2020 15:05:03 INFO 140123020961600] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2023.3569145202637, "sum": 2023.3569145202637, "min": 2023.3569145202637}, "finalize.time": {"count": 1, "max": 251.50585174560547, "sum": 251.50585174560547, "min": 251.50585174560547}, "initialize.time": {"count": 1, "max": 133.54897499084473, "sum": 133.54897499084473, "min": 133.54897499084473}, "check_early_stopping.time": {"count": 15, "max": 1.3759136199951172, "sum": 16.989946365356445, "min": 0.8749961853027344}, "setuptime": {"count": 1, "max": 32.34696388244629, "sum": 32.34696388244629, "min": 32.34696388244629}, "update.time": {"count": 15, "max": 129.28199768066406, "sum": 1361.9871139526367, "min": 54.68297004699707}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1603379103.085171, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1603379101.273738}
# 2020-10-22 15:05:03 Uploading - Uploading generated training model
# 2020-10-22 15:05:44 Completed - Training job completed
# Training seconds: 101
# Billable seconds: 101

# %%
linear_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type='ml.t2.large')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ---------------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

linear_predictor.content_type = 'text/csv'
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

# %%
result = linear_predictor.predict(X_holdout.values)

# %%
predictions = []
for array in np.array_split(X_holdout.values, 100):
    result = linear_predictor.predict(array)
    predictions += [r['predicted_label'] for r in result['predictions']]

predictions = np.array(predictions)

# %% [markdown]
# ## 2.2 Evaluation Metrics for  Linar Model

# %%
auc = metrics.roc_auc_score(y_holdout, predictions)
accuracy = metrics.accuracy_score(y_holdout, predictions)
print(classification_report(y_holdout, predictions))
print('AUC:',auc)
print('Accuracy:',accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        68
#            1       1.00      0.98      0.99        46
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# AUC: 0.9891304347826086
# Accuracy: 0.9912280701754386

# %%
# %matplotlib inline
fpr, tpr, thresholds = metrics.roc_curve(y_holdout, predictions)
auc = metrics.roc_auc_score(y_holdout, predictions)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, marker='.')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.title('ROC curve', fontsize = 20)
plt.xlabel('FPR', fontsize=15)
plt.ylabel('TPR', fontsize=15)
plt.grid()
plt.legend(["AUC=%.3f"%auc])
#plt.show()
plt.savefig("Roc_curve.jpg", dpi=100)

# %%
precision_recall = []
for prediction in predictions:
    precision, recall, _ = precision_recall_curve(y_holdout, predictions)
    precision_recall.append(recall)
    precision_recall.append(precision)

plt.figure(num=None,figsize=(8,6), facecolor='w', edgecolor='k')
plt.plot(*precision_recall)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ## 3.1 Train XGBoost

# %%
X_train, X_holdout, y_train, y_holdout = train_test_split(X,y, test_size=0.20)

# combining train inputs and labels for xgboost
train = pd.concat([y_train, X_train], axis=1)
train.to_csv('train.csv', header=False, index=False)

# %%
prefix='ml-lab'
s3_input_train = boto3.Session().resource('s3').Bucket(bucket)\
                .Object(os.path.join(prefix, 'train.csv')).upload_file('train.csv')

# %%
s3_train_data = s3_input(f's3://{bucket}/ml-lab/train.csv',content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'}
# initialize hyperparameters
hyperparameters = {
        "objective":"binary:logistic",
        "num_round":"200"}

sess = sagemaker.Session()

xgb = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                    role=sagemaker.get_execution_role(),
                                    hyperparameters=hyperparameters,
                                    train_instance_count=1, 
                                    train_instance_type='ml.m5.large',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)


xgb.fit({'train': s3_train_data},job_name=f"job-abalone-{int(time.time())}")
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2020-10-22 16:28:56 Starting - Starting the training job...
# 2020-10-22 16:28:59 Starting - Launching requested ML instances......
# 2020-10-22 16:30:15 Starting - Preparing the instances for training......
# 2020-10-22 16:31:03 Downloading - Downloading input data...
# 2020-10-22 16:31:53 Training - Training image download completed. Training in progress.
# 2020-10-22 16:31:53 Uploading - Uploading generated training model.Arguments: train
# [2020-10-22:16:31:52:INFO] Running standalone xgboost training.
# [2020-10-22:16:31:52:INFO] Path /opt/ml/input/data/validation does not exist!
# [2020-10-22:16:31:52:INFO] File size need to be processed in the node: 0.11mb. Available memory size in the node: 256.43mb
# [2020-10-22:16:31:52:INFO] Determined delimiter of CSV input is ','
# [16:31:52] S3DistributionType set as FullyReplicated
# [16:31:52] 455x30 matrix with 13650 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=4
# [0]#011train-error:0.01978
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [1]#011train-error:0.013187
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=4
# [2]#011train-error:0.006593
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [3]#011train-error:0.006593
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=4
# [4]#011train-error:0.004396
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-error:0.002198
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-error:0.004396
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [7]#011train-error:0.002198
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [8]#011train-error:0.002198
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [9]#011train-error:0.002198
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10]#011train-error:0.002198
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [11]#011train-error:0.002198
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [12]#011train-error:0.002198
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [13]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [15]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [16]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [17]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [18]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [19]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [20]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [21]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [22]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [24]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [25]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [26]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [27]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [28]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [29]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [30]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [31]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [32]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [33]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [34]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [35]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [36]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [37]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [38]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [39]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [40]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [41]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [42]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [43]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [44]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [45]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [46]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [47]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [48]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [49]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [50]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [51]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [52]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [53]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [54]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [55]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [56]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [57]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [58]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [59]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [60]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [61]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [62]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [63]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [64]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [65]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [66]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [67]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [68]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [69]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [70]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [71]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [72]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [73]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [74]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [75]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [76]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [77]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [78]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [79]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [80]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [81]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [82]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [83]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [84]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [85]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [86]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [87]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [88]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [89]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [90]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [91]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [92]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [93]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [94]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [95]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [96]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [97]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [98]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [99]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [100]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [101]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [102]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [103]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [104]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [105]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [106]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [107]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [108]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [109]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [110]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [111]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [112]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [113]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [114]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [115]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [116]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [117]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [118]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [119]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [120]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [121]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [122]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [123]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [124]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [125]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [126]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [127]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [128]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [129]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [130]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [131]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [132]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [133]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [134]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [135]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [136]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [137]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [138]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [139]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [140]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [141]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [142]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [143]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [144]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [145]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [146]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [147]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [148]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [149]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [150]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [151]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [152]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [153]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [154]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [155]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [156]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [157]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [158]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [159]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [160]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [161]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [162]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [163]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [164]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [165]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [166]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [167]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [168]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [169]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [170]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [171]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [172]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [173]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [174]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [175]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [176]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [177]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [178]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [179]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [180]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [181]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [182]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [183]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [184]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [185]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [186]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [187]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [188]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [189]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [190]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [191]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [192]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [193]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [194]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [195]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [196]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [197]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [198]#011train-error:0
# [16:31:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [199]#011train-error:0
# 2020-10-22 16:32:00 Completed - Training job completed
# Training seconds: 57
# Billable seconds: 57

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1, instance_type='ml.t2.large')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!

# %%
xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = None

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions_p = predict(X_holdout.values)
predictions=[round(value) for value in predictions_p]

# %% [markdown]
# ## 3.2 Validation Metrics for XGBOOST

# %%
auc = metrics.roc_auc_score(y_holdout, predictions)
accuracy = metrics.accuracy_score(y_holdout, predictions)
print(classification_report(y_holdout, predictions))
print('AUC:',auc)
print('Accuracy:',accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96        64
#            1       1.00      0.88      0.94        50
#
#     accuracy                           0.95       114
#    macro avg       0.96      0.94      0.95       114
# weighted avg       0.95      0.95      0.95       114
#
# AUC: 0.94
# Accuracy: 0.9473684210526315

# %%
# %matplotlib inline
fpr, tpr, thresholds = metrics.roc_curve(y_holdout, predictions)
auc = metrics.roc_auc_score(y_holdout, predictions)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, marker='.')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.title('ROC curve', fontsize = 20)
plt.xlabel('FPR', fontsize=15)
plt.ylabel('TPR', fontsize=15)
plt.grid()
plt.legend(["AUC=%.3f"%auc])
#plt.show()
plt.savefig("Roc_curve.jpg", dpi=100)

# %%
precision_recall = []
for prediction in predictions:
    precision, recall, _ = precision_recall_curve(y_holdout, predictions)
    precision_recall.append(recall)
    precision_recall.append(precision)

plt.figure(num=None,figsize=(8,6), facecolor='w', edgecolor='k')
plt.plot(*precision_recall)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# THe Linear model seem to be performrimg  much better than XGBoost model, sometimes simple models perform better with the simple dataset, however, the linear model may be overfitting to the dataset because it is not using randomized approach/tree based approach like XGBOOST.It needs to be reavaluated by randomly  training and cross validation to compare the AUC between those groups.
#
# 1. <b>LINEAR AUC:</b> AUC: 0.9891304347826086 | Accuracy: 0.9912280701754386
# 2. <b>XGBOOST AUC:</b> AUC: 0.94 | Accuracy: 0.9473684210526315</br>
#
#
# Overall, both models are doing great, however, XGBoost seem to provide us realistic results, but It can also be improved with more balanced data and better hyperparameter tunning.
